# %% [markdown]
# acess your drive for store data, create the proj dir...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# verify if you setted INVIDIA GPU for the train

# %%
# !nvidia-smi

# %% [markdown]
# clone yoloV5 repo

# %%
# !git clone https://github.com/ultralytics/yolov5

# %%
# create a project folder on the drive
# %mkdir /content/drive/MyDrive/Real_PCB
# copy and paste yolov5 folder to google drive
# %cp -a /content/yolov5 /content/drive/MyDrive/Real_PCB

# %% [markdown]
# upload the dataset and place into projet dir

# %%
# %mkdir /content/drive/MyDrive/Real_PCB/Dataset

# %% [markdown]
# now all the projet struture is created <br>
# so its time for you to upload the dataset avaliable on drive
#
# remember it should look like that:
# ```
# MyDrive/
# └── Real_PCB/
#     ├── Dataset/
#     │   └── pcb_data/
#     │       ├── data.yaml
#     │       ├── test/
#     │       ├── valid/
#     │       └── train/
#     │
#     └── yolov5/
# ```
# :)
#
# install projet's dependencies

# %%
# !pip install -U -r /content/drive/MyDrive/Real_PCB/yolov5/requirements.txt

# %%
# lets move in to yolo dir
# %cd /content/drive/MyDrive/Real_PCB

# %%
import os

# Define the path to the YAML file
yaml_file_path = '/content/drive/MyDrive/Real_PCB/yolov5/runs/train/yolov5s_results4/weights/best.pt'

# Check if the file exists
if os.path.exists(yaml_file_path):
    print("File exists.")
else:
    print("File does not exist or the path is incorrect.")

# %%
# !python ./yolov5/train.py --img 416 --batch 16 --epochs 400 --data ./Dataset/pcb_data/data.yaml --cfg ./yolov5/models/yolov5s.yaml --weights /content/drive/MyDrive/Real_PCB --name yolov5s_results  --cache --device 0

# %% [markdown]
# LET TEST THE MODEL

# %%
# !python ./yolov5/detect.py --weights /content/drive/MyDrive/Real_PCB/yolov5/runs/train/yolov5s_results4/weights/best.pt --img 416 --conf 0.4 --source /content/drive/MyDrive/Real_PCB/Dataset/pcb_data/test/images/VID20210601143927-96_jpg.rf.41cbb5bbd3e96291d5dd3edefda753be.jpg

# %%
from PIL import Image
import matplotlib.pyplot as plt

image_path = '/content/drive/MyDrive/Real_PCB/yolov5/runs/detect/exp2'  # Image file path

# Open the image
image = Image.open(image_path)

# Display the image
plt.imshow(image)
plt.axis('off')  # Turn off axis
plt.show()
